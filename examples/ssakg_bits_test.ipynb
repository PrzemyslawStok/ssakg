# %%
from tests.ssakg_bits_comparison import table_symbols_sequences

no_symbols_list = [1000, 2000]
context_length = 6
sequence_length = 15
number_of_sequences_list = [500, 1000, 1500, 2000, 2500, 3000]
# number_of_sequences_list = [1000, 2000, 3000, 4000, 5000, 6000, 8000, 10000, 11000, 13000]

table2_dataframe, caption = table_symbols_sequences(symbols_list=no_symbols_list,
                                                    number_of_sequences_list=number_of_sequences_list,
                                                    context_length=context_length,
                                                    sequence_length=sequence_length, show_progress=False)

display(table2_dataframe.style.format('{:.3g}').set_caption(caption))
# Out:
# <style type="text/css">
# </style>
# <table id="T_296d4">
#   <caption>Scene recognition error in % for various dataset size for sequence length 15, context length 6.</caption>
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_296d4_level0_col0" class="col_heading level0 col0" >500</th>
#       <th id="T_296d4_level0_col1" class="col_heading level0 col1" >1000</th>
#       <th id="T_296d4_level0_col2" class="col_heading level0 col2" >1500</th>
#       <th id="T_296d4_level0_col3" class="col_heading level0 col3" >2000</th>
#       <th id="T_296d4_level0_col4" class="col_heading level0 col4" >2500</th>
#       <th id="T_296d4_level0_col5" class="col_heading level0 col5" >3000</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >no symbols</th>
#       <th class="index_name level1" >algorithm</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
# ...

# %%
from tests.ssakg_bits_comparison import table_various_context

no_symbols = 2000
context_list = [3, 4, 5, 6, 7]
sequence_length = 15

#number_of_sequences_list = [1000, 2000, 3000, 4000, 5000, 6000, 8000, 10000, 11000, 13000]
number_of_sequences_list = [1000, 1500, 2000, 2500, 3000]

table2_dataframe, caption = table_various_context(no_symbols=no_symbols,
                                                  number_of_sequences_list=number_of_sequences_list,
                                                  context_list=context_list,
                                                  sequence_length=sequence_length, show_progress=False)

display(table2_dataframe.style.format('{:.3g}').set_caption(caption))
